# %%
library(tidyverse) 
library(fpp3)
library(rio) 
library(urca)
k <- 1.5
options(repr.plot.width=6*k, repr.plot.height=5*k)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter()  masks stats::filter()
# ✖ purrr::flatten() masks jsonlite::flatten()
# ✖ dplyr::lag()     masks stats::lag()
# ── Attaching packages ──────────────────────────────────────────── fpp3 0.4.0 ──
#
# ✔ lubridate   1.9.0     ✔ feasts      0.3.0
# ✔ tsibble     1.1.3     ✔ fable       0.3.2
# ✔ tsibbledata 0.4.1
#
# ── Conflicts ───────────────────────────────────────────────── fpp3_conflicts ──
# ✖ lubridate::date()    masks base::date()
# ✖ dplyr::filter()      masks stats::filter()
# ✖ purrr::flatten()     masks jsonlite::flatten()
# ✖ tsibble::intersect() masks base::intersect()
# ✖ tsibble::interval()  masks lubridate::interval()
# ✖ dplyr::lag()         masks stats::lag()
# ✖ tsibble::setdiff()   masks base::setdiff()
# ✖ tsibble::union()     masks base::union()

# %% [markdown]
# ### ARIMA

# %%
m = import('marriages.csv')
m2 = mutate(m, date_round = floor_date(date, unit = 'year'),
            year = year(date_round))
m2
# Out:
#       code        name                          total date       date_round
# 1     30          Центральный федеральный округ 14845 2006-01-01 2006-01-01
# 2     30          Центральный федеральный округ 16414 2006-02-01 2006-01-01
# 3     30          Центральный федеральный округ 15753 2006-03-01 2006-01-01
# 4     30          Центральный федеральный округ 21803 2006-04-01 2006-01-01
# 5     30          Центральный федеральный округ  9384 2006-05-01 2006-01-01
# 6     30          Центральный федеральный округ 29571 2006-06-01 2006-01-01
# 7     30          Центральный федеральный округ 35691 2006-07-01 2006-01-01
# 8     30          Центральный федеральный округ 39263 2006-08-01 2006-01-01
# 9     30          Центральный федеральный округ 40480 2006-09-01 2006-01-01
# 10    30          Центральный федеральный округ 24137 2006-10-01 2006-01-01
# 11    30          Центральный федеральный округ 21207 2006-11-01 2006-01-01
# 12    30          Центральный федеральный округ 19009 2006-12-01 2006-01-01
# 13    30          Центральный федеральный округ 15433 2007-01-01 2007-01-01
# 14    30          Центральный федеральный округ 17430 2007-02-01 2007-01-01
# 15    30          Центральный федеральный округ 13878 2007-03-01 2007-01-01
# 16    30          Центральный федеральный округ 29703 2007-04-01 2007-01-01
# 17    30          Центральный федеральный округ 10529 2007-05-01 2007-01-01
# 18    30          Центральный федеральный округ 31572 2007-06-01 2007-01-01
# 19    30          Центральный федеральный округ 41328 2007-07-01 2007-01-01
# 20    30          Центральный федеральный округ 42609 2007-08-01 2007-01-01
# 21    30          Центральный федеральный округ 41779 2007-09-01 2007-01-01
# 22    30          Центральный федеральный округ 27545 2007-10-01 2007-01-01
# 23    30          Центральный федеральный округ 28827 2007-11-01 2007-01-01
# 24    30          Центральный федеральный округ 27525 2007-12-01 2007-01-01
# 25    30          Центральный федеральный округ 14601 2008-01-01 2008-01-01
# 26    30          Центральный федеральный округ 16440 2008-02-01 2008-01-01
# 27    30          Центральный федеральный округ 20827 2008-03-01 2008-01-01
# 28    30          Центральный федеральный округ 14798 2008-04-01 2008-01-01
# 29    30          Центральный федеральный округ 15293 2008-05-01 2008-01-01
# 30    30          Центральный федеральный округ 32396 2008-06-01 2008-01-01
# ⋮     ⋮           ⋮                             ⋮     ⋮          ⋮
# 20572 99000000000 Еврейская автономная область   94   2019-04-01 2019-01-01
# 20573 99000000000 Еврейская автономная область   33   2019-05-01 2019-01-01
# 20574 99000000000 Еврейская автономная область  103   2019-06-01 2019-01-01
# 20575 99000000000 Еврейская автономная область   91   2019-07-01 2019-01-01
# 20576 99000000000 Еврейская автономная область  130   2019-08-01 2019-01-01
# 20577 99000000000 Еврейская автономная область  113   2019-09-01 2019-01-01
# 20578 99000000000 Еврейская автономная область   79   2019-10-01 2019-01-01
# 20579 99000000000 Еврейская автономная область   74   2019-11-01 2019-01-01
# 20580 99000000000 Еврейская автономная область   92   2019-12-01 2019-01-01
# 20581 99000000000 Еврейская автономная область   58   2020-01-01 2020-01-01
# 20582 99000000000 Еврейская автономная область   79   2020-02-01 2020-01-01
# 20583 99000000000 Еврейская автономная область   76   2020-03-01 2020-01-01
# 20584 99000000000 Еврейская автономная область   59   2020-04-01 2020-01-01
# 20585 99000000000 Еврейская автономная область   25   2020-05-01 2020-01-01
# 20586 99000000000 Еврейская автономная область   81   2020-06-01 2020-01-01
# 20587 99000000000 Еврейская автономная область  104   2020-07-01 2020-01-01
# 20588 99000000000 Еврейская автономная область  119   2020-08-01 2020-01-01
# 20589 99000000000 Еврейская автономная область  104   2020-09-01 2020-01-01
# 20590 99000000000 Еврейская автономная область   97   2020-10-01 2020-01-01
# 20591 99000000000 Еврейская автономная область   79   2020-11-01 2020-01-01
# 20592 99000000000 Еврейская автономная область   92   2020-12-01 2020-01-01
# 20593 99000000000 Еврейская автономная область   53   2021-01-01 2021-01-01
# 20594 99000000000 Еврейская автономная область   53   2021-02-01 2021-01-01
# 20595 99000000000 Еврейская автономная область   64   2021-03-01 2021-01-01
# 20596 99000000000 Еврейская автономная область   80   2021-04-01 2021-01-01
# 20597 99000000000 Еврейская автономная область   40   2021-05-01 2021-01-01
# 20598 99000000000 Еврейская автономная область  106   2021-06-01 2021-01-01
# 20599 99000000000 Еврейская автономная область   96   2021-07-01 2021-01-01
# 20600 99000000000 Еврейская автономная область  108   2021-08-01 2021-01-01
# 20601 99000000000 Еврейская автономная область   78   2021-09-01 2021-01-01
#       year
# 1     2006
# 2     2006
# 3     2006
# 4     2006
# 5     2006
# 6     2006
# 7     2006
# 8     2006
# 9     2006
# 10    2006
# 11    2006
# 12    2006
# 13    2007
# 14    2007
# 15    2007
# 16    2007
# 17    2007
# 18    2007
# 19    2007
# 20    2007
# 21    2007
# 22    2007
# 23    2007
# 24    2007
# 25    2008
# 26    2008
# 27    2008
# 28    2008
# 29    2008
# 30    2008
# ⋮     ⋮
# 20572 2019
# 20573 2019
# 20574 2019
# 20575 2019
# 20576 2019
# 20577 2019
# 20578 2019
# 20579 2019
# 20580 2019
# 20581 2020
# 20582 2020
# 20583 2020
# 20584 2020
# 20585 2020
# 20586 2020
# 20587 2020
# 20588 2020
# 20589 2020
# 20590 2020
# 20591 2020
# 20592 2020
# 20593 2021
# 20594 2021
# 20595 2021
# 20596 2021
# 20597 2021
# 20598 2021
# 20599 2021
# 20600 2021
# 20601 2021

# %%
m3 = select(m2, -date, -date_round)
m3
# Out:
#       code        name                          total year
# 1     30          Центральный федеральный округ 14845 2006
# 2     30          Центральный федеральный округ 16414 2006
# 3     30          Центральный федеральный округ 15753 2006
# 4     30          Центральный федеральный округ 21803 2006
# 5     30          Центральный федеральный округ  9384 2006
# 6     30          Центральный федеральный округ 29571 2006
# 7     30          Центральный федеральный округ 35691 2006
# 8     30          Центральный федеральный округ 39263 2006
# 9     30          Центральный федеральный округ 40480 2006
# 10    30          Центральный федеральный округ 24137 2006
# 11    30          Центральный федеральный округ 21207 2006
# 12    30          Центральный федеральный округ 19009 2006
# 13    30          Центральный федеральный округ 15433 2007
# 14    30          Центральный федеральный округ 17430 2007
# 15    30          Центральный федеральный округ 13878 2007
# 16    30          Центральный федеральный округ 29703 2007
# 17    30          Центральный федеральный округ 10529 2007
# 18    30          Центральный федеральный округ 31572 2007
# 19    30          Центральный федеральный округ 41328 2007
# 20    30          Центральный федеральный округ 42609 2007
# 21    30          Центральный федеральный округ 41779 2007
# 22    30          Центральный федеральный округ 27545 2007
# 23    30          Центральный федеральный округ 28827 2007
# 24    30          Центральный федеральный округ 27525 2007
# 25    30          Центральный федеральный округ 14601 2008
# 26    30          Центральный федеральный округ 16440 2008
# 27    30          Центральный федеральный округ 20827 2008
# 28    30          Центральный федеральный округ 14798 2008
# 29    30          Центральный федеральный округ 15293 2008
# 30    30          Центральный федеральный округ 32396 2008
# ⋮     ⋮           ⋮                             ⋮     ⋮
# 20572 99000000000 Еврейская автономная область   94   2019
# 20573 99000000000 Еврейская автономная область   33   2019
# 20574 99000000000 Еврейская автономная область  103   2019
# 20575 99000000000 Еврейская автономная область   91   2019
# 20576 99000000000 Еврейская автономная область  130   2019
# 20577 99000000000 Еврейская автономная область  113   2019
# 20578 99000000000 Еврейская автономная область   79   2019
# 20579 99000000000 Еврейская автономная область   74   2019
# 20580 99000000000 Еврейская автономная область   92   2019
# 20581 99000000000 Еврейская автономная область   58   2020
# 20582 99000000000 Еврейская автономная область   79   2020
# 20583 99000000000 Еврейская автономная область   76   2020
# 20584 99000000000 Еврейская автономная область   59   2020
# 20585 99000000000 Еврейская автономная область   25   2020
# 20586 99000000000 Еврейская автономная область   81   2020
# 20587 99000000000 Еврейская автономная область  104   2020
# 20588 99000000000 Еврейская автономная область  119   2020
# 20589 99000000000 Еврейская автономная область  104   2020
# 20590 99000000000 Еврейская автономная область   97   2020
# 20591 99000000000 Еврейская автономная область   79   2020
# 20592 99000000000 Еврейская автономная область   92   2020
# 20593 99000000000 Еврейская автономная область   53   2021
# 20594 99000000000 Еврейская автономная область   53   2021
# 20595 99000000000 Еврейская автономная область   64   2021
# 20596 99000000000 Еврейская автономная область   80   2021
# 20597 99000000000 Еврейская автономная область   40   2021
# 20598 99000000000 Еврейская автономная область  106   2021
# 20599 99000000000 Еврейская автономная область   96   2021
# 20600 99000000000 Еврейская автономная область  108   2021
# 20601 99000000000 Еврейская автономная область   78   2021

# %%
m_agg = group_by(m3, code, name, year) %>%
    summarise(sum = sum(total),
              max = max(total),
              .groups = 'keep')
m_agg
# Out:
#      code        name                              year sum    max
# 1    30          Центральный федеральный округ     2006 287557 40480
# 2    30          Центральный федеральный округ     2007 328158 42609
# 3    30          Центральный федеральный округ     2008 300883 50269
# 4    30          Центральный федеральный округ     2009 314089 45051
# 5    30          Центральный федеральный округ     2010 311007 45494
# 6    30          Центральный федеральный округ     2011 338464 44597
# 7    30          Центральный федеральный округ     2012 308879 44401
# 8    30          Центральный федеральный округ     2013 317995 49167
# 9    30          Центральный федеральный округ     2014 322822 48272
# 10   30          Центральный федеральный округ     2015 313157 44041
# 11   30          Центральный федеральный округ     2016 263540 39471
# 12   30          Центральный федеральный округ     2017 284184 42925
# 13   30          Центральный федеральный округ     2018 239977 41523
# 14   30          Центральный федеральный округ     2019 259596 38129
# 15   30          Центральный федеральный округ     2020 205874 33330
# 16   30          Центральный федеральный округ     2021 205118 37089
# 17   31          Северо-Западный федеральный округ 2006 108275 14000
# 18   31          Северо-Западный федеральный округ 2007 120707 15693
# 19   31          Северо-Западный федеральный округ 2008 118454 18003
# 20   31          Северо-Западный федеральный округ 2009 121508 16191
# 21   31          Северо-Западный федеральный округ 2010 122087 16531
# 22   31          Северо-Западный федеральный округ 2011 132872 17334
# 23   31          Северо-Западный федеральный округ 2012 126693 17977
# 24   31          Северо-Западный федеральный округ 2013 126100 18291
# 25   31          Северо-Западный федеральный округ 2014 127466 17346
# 26   31          Северо-Западный федеральный округ 2015 121496 16582
# 27   31          Северо-Западный федеральный округ 2016 105765 15112
# 28   31          Северо-Западный федеральный округ 2017 110143 15432
# 29   31          Северо-Западный федеральный округ 2018  91947 15080
# 30   31          Северо-Западный федеральный округ 2019  99235 13593
# ⋮    ⋮           ⋮                                 ⋮    ⋮      ⋮
# 1715 98000000000 Республика Саха (Якутия)          2008 7408   1388
# 1716 98000000000 Республика Саха (Якутия)          2009 8065   1105
# 1717 98000000000 Республика Саха (Якутия)          2010 8321    986
# 1718 98000000000 Республика Саха (Якутия)          2011 9017   1185
# 1719 98000000000 Республика Саха (Якутия)          2012 7880    995
# 1720 98000000000 Республика Саха (Якутия)          2013 8196   1024
# 1721 98000000000 Республика Саха (Якутия)          2014 7931   1029
# 1722 98000000000 Республика Саха (Якутия)          2015 7668    926
# 1723 98000000000 Республика Саха (Якутия)          2016 6296    803
# 1724 98000000000 Республика Саха (Якутия)          2017 6880    830
# 1725 98000000000 Республика Саха (Якутия)          2018 6030    952
# 1726 98000000000 Республика Саха (Якутия)          2019 6468    788
# 1727 98000000000 Республика Саха (Якутия)          2020 4448    590
# 1728 98000000000 Республика Саха (Якутия)          2021 4264    662
# 1729 99000000000 Еврейская автономная область      2006 1481    199
# 1730 99000000000 Еврейская автономная область      2007 1518    208
# 1731 99000000000 Еврейская автономная область      2008 1572    250
# 1732 99000000000 Еврейская автономная область      2009 1429    183
# 1733 99000000000 Еврейская автономная область      2010 1561    191
# 1734 99000000000 Еврейская автономная область      2011 1509    198
# 1735 99000000000 Еврейская автономная область      2012 1469    207
# 1736 99000000000 Еврейская автономная область      2013 1425    174
# 1737 99000000000 Еврейская автономная область      2014 1334    192
# 1738 99000000000 Еврейская автономная область      2015 1329    163
# 1739 99000000000 Еврейская автономная область      2016 1226    149
# 1740 99000000000 Еврейская автономная область      2017 1263    149
# 1741 99000000000 Еврейская автономная область      2018  962    148
# 1742 99000000000 Еврейская автономная область      2019 1003    130
# 1743 99000000000 Еврейская автономная область      2020  973    119
# 1744 99000000000 Еврейская автономная область      2021  678    108

# %%
rfy = filter(m_agg, code == 643)

# %%
rfy = as_tsibble(rfy, index = year)

# %%
gg_tsdisplay(rfy, sum, plot_type = 'partial')
# Out:
# plot without title

# %%
train = filter(rfy, year < 2018)

# %%
models = model(train,
             ar1 = ARIMA(sum ~ pdq(1, 0, 0)),
             ma1 = ARIMA(sum ~ pdq(0, 0, 1)),
             naive = NAIVE(sum),
             arma11 = ARIMA(sum ~ pdq(1, 0, 1)),
             arima11 = ARIMA(sum ~ pdq(2, 1, 0)))
models
# Out:
#   ar1                    ma1                    naive   arma11
# 1 <ARIMA(1,0,0) w/ mean> <ARIMA(0,0,1) w/ mean> <NAIVE> <ARIMA(1,0,1) w/ mean>
#   arima11
# 1 <ARIMA(2,1,0)>

# %%
report(models$ar1[[1]])
# Out:
# Series: sum
# Model: ARIMA(1,0,0) w/ mean
#
# Coefficients:
#          ar1  constant
#       0.4791  606584.8
# s.e.  0.2704   21593.1
#
# sigma^2 estimated as 7.101e+09:  log likelihood=-152.16
# AIC=310.33   AICc=313.33   BIC=311.78

# %%
nrow(train)
nrow(rfy)
# Out:
# [1] 12
# [1] 16

# %%
fcst = forecast(models, h = 4)

# %%
accuracy(fcst, rfy)
# Out:
#   .model  .type ME        RMSE     MAE      MPE       MAPE     MASE
# 1 ar1     Test  -306492.9 324759.2 306492.9 -38.72332 38.72332 4.280480
# 2 arima11 Test  -189527.6 211321.9 189527.6 -24.31896 24.31896 2.646943
# 3 arma11  Test  -302445.3 321088.8 302445.3 -38.23772 38.23772 4.223951
# 4 ma1     Test  -334470.9 348258.3 334470.9 -41.98675 41.98675 4.671221
# 5 naive   Test  -216716.0 235928.8 216716.0 -27.62012 27.62012 3.026656
#   RMSSE    ACF1
# 1 3.633562 0.2608191
# 2 2.364372 0.2423458
# 3 3.592496 0.2599117
# 4 3.896482 0.2447697
# 5 2.639686 0.2039506

# %%
autoplot(fcst, rfy)
# Out:
# `mutate_if()` ignored the following grouping variables:
# • Columns `code`, `name`, `year`
# plot without title

# %% [markdown]
# ### UR

# %%
marriages <- as_tsibble(m2, index = date,
                       key = c('code', 'name'))
marr_rf <- filter(marriages, code == 643)

# %%
res_kpss = ur.kpss(marr_rf$total, type = 'mu')
summary(res_kpss)
# Out:
# #######################
# # KPSS Unit Root Test #
# #######################
#
# Test is of type: mu with 4 lags.
#
# Value of test-statistic is: 0.5508
#
# Critical value for a significance level of:
#                 10pct  5pct 2.5pct  1pct
# critical values 0.347 0.463  0.574 0.739

# %%
# H0: ts = mu + stat
# Ha: ts = mu + stat + rw

# H0 is rejected

# %%
res_adf = ur.df(marr_rf$total, type = 'none',
            selectlags = 'AIC')
summary(res_adf)
# Out:
# ###############################################
# # Augmented Dickey-Fuller Test Unit Root Test #
# ###############################################
#
# Test regression none
#
#
# Call:
# lm(formula = z.diff ~ z.lag.1 - 1 + z.diff.lag)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -69299 -17772    467  25672  96297
#
# Coefficients:
#            Estimate Std. Error t value Pr(>|t|)
# z.lag.1    -0.04569    0.02453  -1.863   0.0641 .
# z.diff.lag -0.15506    0.07287  -2.128   0.0347 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 32960 on 185 degrees of freedom
# Multiple R-squared:  0.04987,	Adjusted R-squared:  0.0396
# F-statistic: 4.855 on 2 and 185 DF,  p-value: 0.008809
#
#
# Value of test-statistic is: -1.8627
#
# Critical values for test statistics:
#       1pct  5pct 10pct
# tau1 -2.58 -1.95 -1.62

# %%
res_adf = ur.df(marr_rf$total, type = 'drift',
            selectlags = 'AIC')
summary(res_adf)
# Out:
# ###############################################
# # Augmented Dickey-Fuller Test Unit Root Test #
# ###############################################
#
# Test regression drift
#
#
# Call:
# lm(formula = z.diff ~ z.lag.1 + 1 + z.diff.lag)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -70368 -19263  -6312  17675  80349
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  3.843e+04  6.473e+03   5.936 1.42e-08 ***
# z.lag.1     -4.131e-01  6.587e-02  -6.272 2.48e-09 ***
# z.diff.lag   2.681e-02  7.362e-02   0.364    0.716
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 30280 on 184 degrees of freedom
# Multiple R-squared:  0.2026,	Adjusted R-squared:  0.1939
# F-statistic: 23.37 on 2 and 184 DF,  p-value: 9.036e-10
#
#
# Value of test-statistic is: -6.272 19.6767
#
# Critical values for test statistics:
#       1pct  5pct 10pct
# tau2 -3.46 -2.88 -2.57
# phi1  6.52  4.63  3.81

# %%
# H0: ts = ARIMA(p, 1, q) + trend
# Ha: ts = ARIMA(p, 0, q) + const

# H0 is rejected

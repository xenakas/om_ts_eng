# %%
library(tidyverse) 
library(fpp3)
library(rio) 
k = 1.5
options(repr.plot.width=6*k, repr.plot.height=5*k)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter()  masks stats::filter()
# ✖ purrr::flatten() masks jsonlite::flatten()
# ✖ dplyr::lag()     masks stats::lag()
# ── Attaching packages ──────────────────────────────────────────── fpp3 0.4.0 ──
#
# ✔ lubridate   1.9.0     ✔ feasts      0.3.0
# ✔ tsibble     1.1.3     ✔ fable       0.3.2
# ✔ tsibbledata 0.4.1
#
# ── Conflicts ───────────────────────────────────────────────── fpp3_conflicts ──
# ✖ lubridate::date()    masks base::date()
# ✖ dplyr::filter()      masks stats::filter()
# ✖ purrr::flatten()     masks jsonlite::flatten()
# ✖ tsibble::intersect() masks base::intersect()
# ✖ tsibble::interval()  masks lubridate::interval()
# ✖ dplyr::lag()         masks stats::lag()
# ✖ tsibble::setdiff()   masks base::setdiff()
# ✖ tsibble::union()     masks base::union()

# %%
m <- import('marriages.csv')
m2 <- mutate(m, date = yearmonth(date))
marriages <- as_tsibble(m2, index = date,
                       key = c('code', 'name'))
rf <- filter(marriages, code == 643)

# %%
tail(rf)
# Out:
#   code name                 total  date
# 1 643  Российская Федерация  59499 2021 Apr
# 2 643  Российская Федерация  46596 2021 May
# 3 643  Российская Федерация 100908 2021 Jun
# 4 643  Российская Федерация 125068 2021 Jul
# 5 643  Российская Федерация 120961 2021 Aug
# 6 643  Российская Федерация 102528 2021 Sep

# %%
gg_tsdisplay(rf, total)
# Out:
# plot without title

# %%
rf_train <- filter(rf, date < ymd('2019-10-01'))
tail(rf_train)
# Out:
# Warning message in mask$eval_all_filter(dots, env_filter):
# “Incompatible methods ("<.vctrs_vctr", "<.Date") for "<"”
#   code name                 total  date
# 1 643  Российская Федерация  56818 2019 Apr
# 2 643  Российская Федерация  43531 2019 May
# 3 643  Российская Федерация 104709 2019 Jun
# 4 643  Российская Федерация 112845 2019 Jul
# 5 643  Российская Федерация 133217 2019 Aug
# 6 643  Российская Федерация 107033 2019 Sep

# %%
mods <- model(rf_train,
      snaive = SNAIVE(total),
      ana = ETS(total ~ error('A') + trend('N') + season('A')),
      aadm = ETS(total ~ error('A') + trend('Ad') + season('M')),
      zzz = ETS(total),
      azz = ETS(total ~ error('A')),
      theta = THETA(total)
)
mods
# Out:
#   code name                 snaive   ana          aadm          zzz
# 1 643  Российская Федерация <SNAIVE> <ETS(A,N,A)> <ETS(A,Ad,M)> <ETS(M,N,M)>
#   azz          theta
# 1 <ETS(A,N,A)> <THETA>

# %%
report(mods$zzz[[1]])
# Out:
# Series: total
# Model: ETS(M,N,M)
#   Smoothing parameters:
#     alpha = 0.117708
#     gamma = 0.0001002307
#
#   Initial states:
#     l[0]      s[0]     s[-1]    s[-2]    s[-3]   s[-4]    s[-5]    s[-6]
#  98860.5 0.8778057 0.9038713 1.029667 1.440791 1.63612 1.460428 1.248881
#      s[-7]     s[-8]     s[-9]    s[-10]   s[-11]
#  0.4754327 0.9410506 0.7282367 0.6792146 0.578501
#
#   sigma^2:  0.017
#
#      AIC     AICc      BIC
# 3948.919 3952.141 3995.509

# %%
report(mods$theta[[1]])
# Out:
# Series: total
# Model: THETA
#
# Alpha: 0.1383
# Drift: -71.765
# sigma^2: 142426264.9441

# %%
fcst <- forecast(mods, h = 12)

# %%
accuracy(fcst, rf)
# Out:
# Error in accuracy(fcst, rf): object 'fcst' not found
# Traceback:
#
# 1. accuracy(fcst, rf)

# %%
plot(fcst)
